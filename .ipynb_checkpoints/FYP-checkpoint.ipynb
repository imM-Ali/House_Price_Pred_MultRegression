# %%
#pip install mlxtend

# %%
#pip install imblearn

# %%
#pip install geopandas

# %%
#pip install category_encoders

# %%
#pip install xgboost

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import geopandas as gpd
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
import category_encoders as ce
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from imblearn.over_sampling import SMOTE

# %%
data = pd.read_csv("daft.csv")

# %%
data.head()
# Out:
#         id                                              title featuredLevel  \
# 0  3626025  11 Chestnut Crescent, Bridgemount, Carrigaline...      featured
# 1  3675175  58 The Glen, Kilnacourt Woods, Portarlington, ...      featured
# 2  3673450        16 Dodderbrook Park, Ballycullen, Dublin 24      featured
# 3  3649708      31 Lissanalta Drive, Dooradoyle, Co. Limerick      featured
# 4  3643947                5 Columba Terrace, Kells, Co. Meath      featured
#
#   publishDate   price  numBedrooms  numBathrooms    propertyType  \
# 0  2022-01-28  290000            3             3  End of Terrace
# 1  2022-01-28  225000            3             2          Semi-D
# 2  2022-01-27  575000            4             3          Semi-D
# 3  2022-01-28  299000            3             3          Semi-D
# 4  2022-01-28  120000            3             1         Terrace
#
#    propertySize category  ...       seller_name              seller_branch  \
# 0          96.0      Buy  ...       Roy Dennehy        Dennehy Auctioneers
# 1          93.0      Buy  ...     Marie Kiernan  Tom McDonald & Associates
# 2         162.0      Buy  ...          Moovingo                   Moovingo
# 3           NaN      Buy  ...  DNG Cusack Dunne           DNG Cusack Dunne
# 4          68.0      Buy  ...   REA T&J Gavigan          REA T & J Gavigan
#
#       sellerType m_totalImages m_hasVideo  m_hasVirtualTour  m_hasBrochure  \
# 0  BRANDED_AGENT          16.0      False             False          False
# 1  BRANDED_AGENT          33.0      False             False          False
# 2  BRANDED_AGENT          38.0      False              True          False
# 3  BRANDED_AGENT          22.0      False             False          False
# 4  BRANDED_AGENT           5.0      False             False          False
#
#    ber_rating  longitude   latitude
# 0          C2  -8.382500  51.822940
# 1          C1  -7.177098  53.157465
# 2          A3  -6.342763  53.269493
# 3          C2  -8.640716  52.629588
# 4           G  -6.879797  53.728601
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Data Explanation

# %% [markdown]
# ##### Data Source : Daft.ie
# * id: Property listing id used in the website
# * title: property address.
# * featuredLevel: ['featured' 'premium' 'standard']
# * publishDate: published date for the listing.
# * price: house price.
# * numBedrooms: No. of bedrooms.
# * numBathrooms: No. of bathroom.
# * propertyType: ['End of Terrace' 'Semi-D' 'Terrace' 'Detached' 'Apartment' 'Bungalow'
# 'Townhouse' 'Duplex' 'Site' 'Studio' 'House'.
# * propertySize: Size of the property in meters squared
# * category: ['Buy' 'New Homes'] (Buy means the houses listed under Buy menu in the websites)
# * AMVprice: Advised minimum value (some properties have AMV price. The price column was mixed with regular price and AMV price, created a new column for AMV price to flag if it is AMV or not.)
# * sellerId: Seller's Id
# * sellername: Seller's name
# * sellerbranch: Seller's branch if it is an agency.
# * sellerType: ['BRANDEDAGENT' 'UNBRANDEDAGENT' 'PRIVATEUSER']
# * m_totalImages: Total images posted on the website.
# * m_hasVideo: Whether the property posted a video or not.
# * m_hasVirtualTour: Whether the property has a virtual tour or not.
# * m_hasBrochure: Whether the property has a brochure or not.
# * longitude: Coordinate
# * latitude: Coordinate
# * ber_rating: ['C2' 'C1' 'A3' 'G' 'D2' 'B3' 'D1' 'C3' 'E1' 'SI666' 'F' 'E2' 'B2' 'XXX', 'A2,''B1' 'A1' 'A1A2']
# (XXX means the rating was missing)
# ]

# %% [markdown]
# #### Quick peek into the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3967 entries, 0 to 3966
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3967 non-null   int64
#  1   title             3967 non-null   object
#  2   featuredLevel     3967 non-null   object
#  3   publishDate       3967 non-null   object
#  4   price             3967 non-null   int64
#  5   numBedrooms       3967 non-null   int64
#  6   numBathrooms      3967 non-null   int64
#  7   propertyType      3967 non-null   object
#  8   propertySize      3612 non-null   float64
#  9   category          3967 non-null   object
#  10  AMV_price         3967 non-null   int64
#  11  sellerId          3967 non-null   float64
#  12  seller_name       3967 non-null   object
#  13  seller_branch     3967 non-null   object
#  14  sellerType        3967 non-null   object
#  15  m_totalImages     3967 non-null   float64
#  16  m_hasVideo        3967 non-null   bool
#  17  m_hasVirtualTour  3967 non-null   bool
#  18  m_hasBrochure     3967 non-null   bool
#  19  ber_rating        3967 non-null   object
#  20  longitude         3967 non-null   float64
#  21  latitude          3967 non-null   float64
# dtypes: bool(3), float64(5), int64(5), object(9)
# memory usage: 600.6+ KB

# %% [markdown]
# #### Categorical Data
# * featuredLevel, propertyType, category,  sellerType, seller_branch, seller_name, ber_rating, title, id, sellerId, m_hasVideo, m_hasBrochure, m_hasVirtualTour
# #### Numerical Data
# Continouous:
# * price, numBedrooms, numBathrooms, latitude, longitude, m_totalImages, AMV_price, , propertySize.
#
# Disrete:
# * publishDate

# %%
data.describe().transpose()
# Out:
#                 count          mean            std           min  \
# id             3967.0  3.629047e+06  250247.854757  10921.000000
# price          3967.0  3.416734e+05  270358.241779  20000.000000
# numBedrooms    3967.0  3.126292e+00       1.230570      1.000000
# numBathrooms   3967.0  2.077136e+00       1.167772      1.000000
# propertySize   3612.0  1.326739e+02     295.246580      1.000000
# AMV_price      3967.0  4.739098e-02       0.212500      0.000000
# sellerId       3967.0  2.163815e+04  254150.598747      7.000000
# m_totalImages  3967.0  1.844895e+01      10.537226      0.000000
# longitude      3967.0 -7.389964e+00       1.865587   -100.445882
# latitude       3967.0  5.313382e+01       0.716435     39.783730
#
#                         25%           50%           75%           max
# id             3.654066e+06  3.673795e+06  3.685990e+06  3.695402e+06
# price          1.950000e+05  2.750000e+05  3.950000e+05  4.500000e+06
# numBedrooms    2.000000e+00  3.000000e+00  4.000000e+00  2.300000e+01
# numBathrooms   1.000000e+00  2.000000e+00  3.000000e+00  2.300000e+01
# propertySize   7.800000e+01  1.030000e+02  1.370000e+02  8.600000e+03
# AMV_price      0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# sellerId       2.178000e+03  3.255000e+03  8.806000e+03  5.310328e+06
# m_totalImages  1.200000e+01  1.700000e+01  2.300000e+01  1.040000e+02
# longitude     -8.426627e+00 -7.050391e+00 -6.298945e+00 -6.028016e+00
# latitude       5.266612e+01  5.330335e+01  5.343872e+01  5.529969e+01

# %% [markdown]
# #### Checking for Null Values

# %%
for i in data[data.columns[data.isnull().any()]].columns:
    print('- ',i)
# Out:
# -  propertySize

# %% [markdown]
# #### propertySize is missing around 355 values, which is around 10% of the total, hence dropping the records will impact the performance of our model therefore we need to fill the missing values with the median value.
# If the data is heavily skewed or has outliers, the median is a better choice as it is robust to extreme values. The median represents the middle value and is less influenced by extreme observations.

# %%
median_value = data['propertySize'].median() 
data['propertySize'].fillna(value=median_value, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3967 entries, 0 to 3966
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3967 non-null   int64
#  1   title             3967 non-null   object
#  2   featuredLevel     3967 non-null   object
#  3   publishDate       3967 non-null   object
#  4   price             3967 non-null   int64
#  5   numBedrooms       3967 non-null   int64
#  6   numBathrooms      3967 non-null   int64
#  7   propertyType      3967 non-null   object
#  8   propertySize      3967 non-null   float64
#  9   category          3967 non-null   object
#  10  AMV_price         3967 non-null   int64
#  11  sellerId          3967 non-null   float64
#  12  seller_name       3967 non-null   object
#  13  seller_branch     3967 non-null   object
#  14  sellerType        3967 non-null   object
#  15  m_totalImages     3967 non-null   float64
#  16  m_hasVideo        3967 non-null   bool
#  17  m_hasVirtualTour  3967 non-null   bool
#  18  m_hasBrochure     3967 non-null   bool
#  19  ber_rating        3967 non-null   object
#  20  longitude         3967 non-null   float64
#  21  latitude          3967 non-null   float64
# dtypes: bool(3), float64(5), int64(5), object(9)
# memory usage: 600.6+ KB

# %% [markdown]
# #### Price Distribution

# %%
plt.figure(figsize=(10, 6))
sns.displot(data['price'])
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# * Majority of the house pricing is under half a million. With a few houses being nearly 3 million!
# * Price is heavily right skewed

# %% [markdown]
# #### Price vs Size of property

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="price", y="propertySize", data=data)
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# * In the cluster, a weak trend of increasing prices with increasing property size can be seen. However, there are few records where the property size has increased but the price is still near the lowest. This could indicate errors in the data.
#
# #### Number of Bedrooms vs Price

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x="numBedrooms", y="price")
# Out:
# <Axes: xlabel='numBedrooms', ylabel='price'>

# %% [markdown]
# * We can see that the prices tend to go up with the number of bedrooms.
# * The price variance in houses with lower number of bedrooms is lower as compared to the variance in prices of houses with high number of bedrooms.
# * Visible values that are outside of the 75th percentile.

# %%
grouped_data = data.groupby('ber_rating')['price'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='ber_rating', y='price', data=grouped_data)
plt.xlabel('BER Rating')
plt.ylabel('Price')
plt.title('Average House Price by Energy Rating')
plt.tight_layout()

# %% [markdown]
# * According to https://www.seai.ie/home-energy/building-energy-rating-ber/understand-a-ber-rating , Sl_666 and XXX are possible errors.
# * The average size house rating in ireland is D2, we can see that prices take a dip around this area which shows market competition.
# * The price of A1A2 rated house seems lower than the average, considering A1A2 is not a real rating, this will be explored further.

# %% [markdown]
# #### Price Trends Respective to the Type of Property

# %%
plt.figure(figsize=(15, 6))
grouped_data = data.groupby('propertyType')['price'].mean().reset_index()
sns.boxplot(x='propertyType',y='price',data=grouped_data)
# Out:
# <Axes: xlabel='propertyType', ylabel='price'>

# %% [markdown]
# * As per daft.ie, a 'House' is any property irrelevant of its type. Following this, the average price for a 'house' should be in the middle of all other values, but in the figure above, it is the highest averaging type, this shows rare records or possibly outliers
# * Detached houses are the most costly, whereas studios are the cheapest to buy.

# %% [markdown]
# #### Biggest Market Share By Investor

# %%
grouped_data = data.groupby('seller_branch')['price'].sum().reset_index()
grouped_data = grouped_data.sort_values(by=['price'], ascending=False)
top_5 = grouped_data.head(5)

# %%
plt.figure(figsize=(22, 10))
sns.barplot(top_5, x="seller_branch", y="price")
plt.ticklabel_format(style='plain', axis='y')

# %% [markdown]
# * BidX1 has the largest market share of 40 million!
# * Private owners have the 4th highest share of properties.

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# * Converting Date to DateTime and splitting into Year and Month

# %%
data['publishDate'] = pd.to_datetime(data['publishDate'])

# %%
data['year'] = data['publishDate'].dt.year
data['month'] = data['publishDate'].dt.month

data.drop(['publishDate'], axis=1, inplace = True)

# %% [markdown]
# * Using clustering to replace latitude and longitude with a location cluster as the co-ordinates themselves do not present any usability for ML according to the source below.
#
# https://heartbeat.comet.ml/working-with-geospatial-data-in-machine-learning-ad4097c7228d

# %%
kmeans = KMeans(5)
clusters = kmeans.fit_predict(data[['latitude','longitude']])
data['zone'] = kmeans.predict(data[['latitude','longitude']])
data.drop(['latitude', 'longitude'], axis=1, inplace = True)
# Out:
# C:\Users\Ali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Ali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=16.
#   warnings.warn(

# %% [markdown]
# * Extracting county and Town from Address.

# %%
def getCounty(title):
    address_parts = title.split(',')
    return address_parts[-1].strip()

# %%
def getTown(title):
    address_parts = title.split(',')
    return address_parts[-2].strip()

# %%
data['county'] = data['title'].apply(getCounty)

# %%
data['town'] = data['title'].apply(getTown)

# %%
data.drop(['title'], axis=1, inplace = True)

# %%
data['county'] = data['county'].str.replace('Co. ', '')

# %%
data['county'] = data['county'].str.extract(r'([a-zA-Z]+)')

# %%
data['town'] = data['town'].str.extract(r'([a-zA-Z]+)')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3967 entries, 0 to 3966
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3967 non-null   int64
#  1   featuredLevel     3967 non-null   object
#  2   price             3967 non-null   int64
#  3   numBedrooms       3967 non-null   int64
#  4   numBathrooms      3967 non-null   int64
#  5   propertyType      3967 non-null   object
#  6   propertySize      3967 non-null   float64
#  7   category          3967 non-null   object
#  8   AMV_price         3967 non-null   int64
#  9   sellerId          3967 non-null   float64
#  10  seller_name       3967 non-null   object
#  11  seller_branch     3967 non-null   object
#  12  sellerType        3967 non-null   object
#  13  m_totalImages     3967 non-null   float64
#  14  m_hasVideo        3967 non-null   bool
#  15  m_hasVirtualTour  3967 non-null   bool
#  16  m_hasBrochure     3967 non-null   bool
#  17  ber_rating        3967 non-null   object
#  18  year              3967 non-null   int32
#  19  month             3967 non-null   int32
#  20  zone              3967 non-null   int32
#  21  county            3967 non-null   object
#  22  town              3967 non-null   object
# dtypes: bool(3), float64(3), int32(3), int64(5), object(9)
# memory usage: 585.1+ KB

# %% [markdown]
# #### Domain Knowledge
# * Dropping Advertisement ID as it is a daft.ie listing identifier and the ML model may interpret this as a mathematical input.
# * Example: If a house with id 1 is priced at 200,000 and another house with id 45 is priced at 500,000 the machine learning model might
# interpret this as if the id goes up, the price will also go up, which is completely incorrect.

# %%
data.drop(['id'], axis=1, inplace = True)

# %%
data.drop(['sellerId'], axis=1, inplace = True)

# %% [markdown]
# #### Average House Price by Month

# %%
plt.figure(figsize=(15, 6))
data.groupby('month')['price'].mean().plot()
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# * Price of housing tends to fall by almost 20000 during the last month of the year.

# %% [markdown]
# #### A look into the distribution of data

# %%
data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'numBedrooms'}>,
#         <Axes: title={'center': 'numBathrooms'}>],
#        [<Axes: title={'center': 'propertySize'}>,
#         <Axes: title={'center': 'AMV_price'}>,
#         <Axes: title={'center': 'm_totalImages'}>],
#        [<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'month'}>,
#         <Axes: title={'center': 'zone'}>]], dtype=object)

# %% [markdown]
# * Data is skewed and unbalanced.

# %% [markdown]
# #### Test Train Split

# %% [markdown]
# https://onlinelibrary.wiley.com/doi/full/10.1002/sam.11583
# * According to this study, the best test to train split ratio is the square root of number of features to 1. We have 22 features which gives us around 4.6:1 , which means the best split is 75/25.

# %%
X = data.drop(['price'], axis=1)
y = data['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=42)

# %%
train_data = X_train.join(y_train)

# %%
train_data.head()
# Out:
#      featuredLevel  numBedrooms  numBathrooms propertyType  propertySize  \
# 3195      standard            5             1     Detached         138.0
# 2307      standard            4             1     Detached         174.0
# 111       featured            4             3     Detached         204.0
# 2329      standard            3             3     Detached         149.0
# 1089      standard            3             1     Detached         103.0
#
#      category  AMV_price        seller_name  \
# 3195      Buy          0      Eamon Scanlon
# 2307      Buy          1        Marc Browne
# 111       Buy          0  Raymond Potterton
# 2329      Buy          0   Geraldine Tracey
# 1089      Buy          0    Daragh Heraghty
#
#                                       seller_branch       sellerType  ...  \
# 3195  E & M Scanlon Auctioneers & Estate Agents Ltd  UNBRANDED_AGENT  ...
# 2307                                   DNG Tallaght    BRANDED_AGENT  ...
# 111                                 Glenveagh Homes  UNBRANDED_AGENT  ...
# 2329          Team Lorraine Mulligan RE/MAX Results    BRANDED_AGENT  ...
# 1089                     Daragh Heraghty Auctioneer    BRANDED_AGENT  ...
#
#       m_hasVideo  m_hasVirtualTour  m_hasBrochure  ber_rating  year  month  \
# 3195       False             False          False           G  2021     12
# 2307       False              True          False          A2  2022      1
# 111        False             False           True          A3  2022      1
# 2329       False             False          False          D2  2022      1
# 1089       False             False          False          D2  2022      1
#
#       zone     county          town   price
# 3195     3    Donegal          Muff  200000
# 2307     4    Wexford       Wexford  195000
# 111      4    Wicklow     Roundwood  450000
# 2329     4    Kildare  Monasterevin  390000
# 1089     3  Roscommon         Boyle  150000
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Encodings

# %% [markdown]
# * Emphasis has been put on keeping the dimensionality of the dataset as low as possible.
# * Label encoding was tested and resulted in values being used as ordinal, therefore, other types of encoding was preffered.
# * Label encoders work well only with decision tree based algorithms, where as we want to use linear models.

# %% [markdown]
# #### One Hot Encodings. propertyType, category, sellerType.

# %% [markdown]
# * Reasoning: High cardinality features result in increased memory usage due to the amount of dummy variables required to encode them which reduces the models performance. Therefore, they should be grouped based on some criteria and then encoded.
# * https://towardsdatascience.com/dealing-with-features-that-have-high-cardinality-1c9212d7ff1b

# %% [markdown]
# #### Ordinal Encodings. featuredLevel, ber_rating

# %% [markdown]
# * Reasoning: As the cardinality is relatively lower (only 3 unique values) and the values follow a natural progression.
# * According to daft.ie : standard < premium < featured.

# %% [markdown]
# #### Target Encoding : town, county, sellername and seller branch

# %% [markdown]
# * Leave one out encoding
# * Reasoning: As we have so many distinct values, for every row, LOO will calculate the mean of targets without the current data point in calculations. This prevents data leakage and there is no additional dimensionality.
# * https://medium.com/anolytics/all-you-need-to-know-about-encoding-techniques-b3a0af68338b#:~:text=Leave%2DOne%2DOut%20Encoding%20(,which%20belongs%20to%20that%20category.

# %%
def encode(df):
    df['propertyType'].replace(['End of Terrace', 'Bungalow', 'Townhouse', 'Duplex', 'Site', 'House', 'Studio'], 'Other', inplace=True)
    df  = pd.get_dummies(df, columns = ['propertyType'], dtype=float)
    df  = pd.get_dummies(df, columns = ['category'], dtype=float)
    df  = pd.get_dummies(df, columns = ['sellerType'], dtype=float)
    
    featuredLevels = ['standard', 'premium', 'featured']
    ber_ratings = ['XXX', 'SI_666', 'G', 'F', 'E2', 'E1', 'D2', 'D1', 'C3', 'C2', 'C1', 'B3', 'B2', 'B1', 'A3', 'A2', 'A1A2', 'A1']

    encoder = OrdinalEncoder(categories=[featuredLevels, ber_ratings])
    df[['featuredLevel', 'ber_rating']] = encoder.fit_transform(df[['featuredLevel', 'ber_rating']]) 
    
    #df['county'] = df['county'].where(df['county'].isin(['Dublin', 'Limerick', 'Kildare', 'Galway', 'Louth', 'Cork', 'Mayo', 'Westmeath', 'Wexford', 'Kerry', 'Meath', 'Donegal', 'Roscommon', 'Wicklow', 'Waterford', 'Tipperary', 'Clare', 'Laois', 'Offaly', 'Kilkenny', 'Sligo', 'Cavan', 'Carlow', 'Leitrim', 'Longford', 'Monaghan']), other='Other')
    df['county'] = df['county'].where(df['county'].isin(['Dublin']), other='Other')
    df  = pd.get_dummies(df, columns = ['county'], dtype=float)
    #encoder = ce.LeaveOneOutEncoder(cols=['county'])
    #data_encoded = encoder.fit_transform(df['county'], df['price'])
    #df = df.merge(data_encoded, how = 'left', left_index=True, right_index=True)
    #df.drop(['county_x'], axis=1, inplace = True)
    
    encoder = ce.LeaveOneOutEncoder(cols=['town'])
    data_encoded = encoder.fit_transform(df['town'], df['price'])
    df = df.merge(data_encoded, how = 'left', left_index=True, right_index=True)
    df.drop(['town_x'], axis=1, inplace = True)

    encoder = ce.LeaveOneOutEncoder(cols=['seller_branch'])
    data_encoded = encoder.fit_transform(df['seller_branch'], df['price'])
    df = df.merge(data_encoded, how = 'left', left_index=True, right_index=True)
    df.drop(['seller_branch_x'], axis=1, inplace = True)
    
    encoder = ce.LeaveOneOutEncoder(cols=['seller_name'])
    data_encoded = encoder.fit_transform(df['seller_name'], df['price'])
    df = df.merge(data_encoded, how = 'left', left_index=True, right_index=True)
    df.drop(['seller_name_x'], axis=1, inplace = True)
   
   
    
    df[['m_hasVideo','m_hasVirtualTour', 'm_hasBrochure']] = df[['m_hasVideo','m_hasVirtualTour', 'm_hasBrochure']].astype(float)
           
    return df

# %%
train_data = encode(train_data)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2776 entries, 3195 to 3174
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   featuredLevel               2776 non-null   float64
#  1   numBedrooms                 2776 non-null   int64
#  2   numBathrooms                2776 non-null   int64
#  3   propertySize                2776 non-null   float64
#  4   AMV_price                   2776 non-null   int64
#  5   m_totalImages               2776 non-null   float64
#  6   m_hasVideo                  2776 non-null   float64
#  7   m_hasVirtualTour            2776 non-null   float64
#  8   m_hasBrochure               2776 non-null   float64
#  9   ber_rating                  2776 non-null   float64
#  10  year                        2776 non-null   int32
#  11  month                       2776 non-null   int32
#  12  zone                        2776 non-null   int32
#  13  price                       2776 non-null   int64
#  14  propertyType_Apartment      2776 non-null   float64
#  15  propertyType_Detached       2776 non-null   float64
#  16  propertyType_Other          2776 non-null   float64
#  17  propertyType_Semi-D         2776 non-null   float64
#  18  propertyType_Terrace        2776 non-null   float64
#  19  category_Buy                2776 non-null   float64
#  20  category_New Homes          2776 non-null   float64
#  21  sellerType_BRANDED_AGENT    2776 non-null   float64
#  22  sellerType_PRIVATE_USER     2776 non-null   float64
#  23  sellerType_UNBRANDED_AGENT  2776 non-null   float64
#  24  county_Dublin               2776 non-null   float64
#  25  county_Other                2776 non-null   float64
#  26  town_y                      2776 non-null   float64
#  27  seller_branch_y             2776 non-null   float64
#  28  seller_name_y               2776 non-null   float64
# dtypes: float64(22), int32(3), int64(4)
# memory usage: 682.6 KB

# %%
plt.figure(figsize=(10, 15))
sns.heatmap(train_data.corr()[['price']].sort_values(by='price', ascending=False), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
#  ----------------------------------------------------------------------

# %% [markdown]
# #### Normalizing Data

# %% [markdown]
# * Normalizing the whole sets including target variable provides a better fit and increases the R2 scores by 6% in our case.
# * Will need to transform the output.
# * Otherwise, datasets can be normalized except the target variable.

# %%
from sklearn.preprocessing import normalize

train_data['propertySize'] = np.log(train_data['propertySize']+1)
train_data['numBedrooms'] = np.log(train_data['numBedrooms']+1)
train_data['numBathrooms'] = np.log(train_data['numBathrooms']+1)

orig_train = train_data.astype(float)
f = normalize(train_data, norm="l2")
train_data = pd.DataFrame(data=f, columns=train_data.columns)


test_data = X_test.join(y_test)
test_data = encode(test_data)

test_data['propertySize'] = np.log(test_data['propertySize']+1)
test_data['numBedrooms'] = np.log(test_data['numBedrooms']+1)
test_data['numBathrooms'] = np.log(test_data['numBathrooms']+1)

orig_test = test_data.astype(float)
f = normalize(test_data, norm="l2")
test_data = pd.DataFrame(data=f, columns=test_data.columns)

# To replace target variables with original values.
train_data['price'] = orig_train['price'].values
test_data['price'] = orig_test['price'].values

# %%
X_train, y_train = train_data.drop(['price'], axis=1), train_data['price']
X_test, y_test = test_data.drop(['price'], axis=1), test_data['price']

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

fs = SelectKBest(score_func=f_regression, k=10)

X_selected = fs.fit_transform(X_train, y_train)
cols_from_k=X_train.columns[fs.get_support(indices=True)]
cols_from_k
# Out:
# Index(['numBedrooms', 'propertySize', 'm_totalImages', 'ber_rating', 'year',
#        'zone', 'category_Buy', 'county_Other', 'seller_branch_y',
#        'seller_name_y'],
#       dtype='object')

# %%
X_train = train_data[cols_from_k]
X_test = test_data[cols_from_k]

# %%
X_train
# Out:
#       numBedrooms  propertySize  m_totalImages  ber_rating      year  \
# 0        0.000003      0.000008       0.000030    0.000003  0.003209
# 1        0.000003      0.000010       0.000037    0.000030  0.003980
# 2        0.000002      0.000007       0.000001    0.000018  0.002661
# 3        0.000002      0.000007       0.000035    0.000009  0.002973
# 4        0.000005      0.000016       0.000044    0.000020  0.006825
# ...           ...           ...            ...         ...       ...
# 2771     0.000002      0.000011       0.000049    0.000008  0.004293
# 2772     0.000002      0.000006       0.000028    0.000013  0.002532
# 2773     0.000002      0.000007       0.000019    0.000015  0.003282
# 2774     0.000003      0.000009       0.000039    0.000027  0.003894
# 2775     0.000001      0.000006       0.000014    0.000012  0.002526
#
#           zone  category_Buy  county_Other  seller_branch_y  seller_name_y
# 0     0.000005      0.000002      0.000002         0.555792       0.543240
# 1     0.000008      0.000002      0.000002         0.614769       0.494265
# 2     0.000005      0.000001      0.000001         0.542326       0.568794
# 3     0.000006      0.000001      0.000001         0.505797       0.505797
# 4     0.000010      0.000003      0.000003         0.506333       0.506333
# ...        ...           ...           ...              ...            ...
# 2771  0.000008      0.000002      0.000002         0.394420       0.392751
# 2772  0.000003      0.000001      0.000001         0.493059       0.435050
# 2773  0.000006      0.000002      0.000000         0.555222       0.555222
# 2774  0.000004      0.000002      0.000000         0.510330       0.510330
# 2775  0.000005      0.000001      0.000000         0.426096       0.471532
#
# [2776 rows x 10 columns]

# %%
X_train.hist(figsize=(15,10));

# %% [markdown]
# #### Model Selection

# %% [markdown]
# #### Regression Models

# %%
def evaluation(y, predictions):
    mae = mean_absolute_error(y, predictions)
    mse = mean_squared_error(y, predictions)
    rmse = np.sqrt(mean_squared_error(y, predictions))
    r_squared = r2_score(y, predictions)
    return mae, mse, rmse, r_squared

# %%
evals = pd.DataFrame(columns=["Model","MAE","MSE","RMSE","R2 Score"])

# %%
testing = np.asarray([[4,3,293,40, 0, 2024, 1, 0, 245500, 269000]])

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_test_s = scaler.transform(X_test)

# %%
y_pred = reg.predict(X_test_s)

# %%
reg.predict(testing)
# Out:
# array([-4.09919555e+10])

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 92533.45910710099
# MSE: 26225390004.761833
# RMSE: 161942.5515569081
# R2 Score: 0.6410129902387808
# ------------------------------

# %%
new_row = {"Model": "LinearRegression","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)
# Out:
# C:\Users\Ali\AppData\Local\Temp\ipykernel_26568\2724288395.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# #### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = forest.predict(X_test_s)

# %%
forest.predict(testing)
# Out:
# array([154758.])

# %%
feat_importances = pd.Series(forest.feature_importances_, index=X_train.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.title("Top 15 important features")
plt.show()

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 63275.17347607053
# MSE: 16450991175.30095
# RMSE: 128261.41732922239
# R2 Score: 0.774810131381948
# ------------------------------

# %%
new_row = {"Model": "Random Forest","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# #### SVR

# %%
svr = SVR(C=10000)
svr.fit(X_train_s, y_train)
y_pred = svr.predict(X_test_s)

# %%
svr.predict(testing)
# Out:
# array([239272.63653564])

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 62015.41714813552
# MSE: 15200857375.421751
# RMSE: 123291.75712683209
# R2 Score: 0.7919226240670358
# ------------------------------

# %%
new_row = {"Model": "SVR","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# #### XGBoost Regressor

# %%
xgb = XGBRegressor(n_estimators=1000, learning_rate=0.001)
xgb.fit(X_train_s, y_train)
y_pred = xgb.predict(X_test_s)

# %%
xgb.predict(testing)
# Out:
# array([240543.1], dtype=float32)

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 90421.59200514274
# MSE: 23759338936.44733
# RMSE: 154140.64660707547
# R2 Score: 0.674769601628428
# ------------------------------

# %%
new_row = {"Model": "XGBoost","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
#  #### Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(X_train_s, y_train)
y_pred = ridge.predict(X_test_s)

# %%
ridge.predict(testing)
# Out:
# array([-4.09917126e+10])

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 92510.93245770024
# MSE: 26224011251.488674
# RMSE: 161938.2945800303
# R2 Score: 0.6410318633428467
# ------------------------------

# %%
new_row = {"Model": "Ridge","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# ----------------

# %% [markdown]
#  #### Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()
lasso.fit(X_train_s, y_train)
y_pred = lasso.predict(X_test_s)

# %%
lasso.predict(testing)
# Out:
# array([-4.09917322e+10])

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 92532.59126375358
# MSE: 26225314759.653896
# RMSE: 161942.31923636852
# R2 Score: 0.6410140202336176
# ------------------------------

# %%
new_row = {"Model": "Lasso","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# ------------------

# %% [markdown]
#  #### Elastic Net

# %%
X_train_s
# Out:
# array([[ 1.10753397,  0.37350297,  0.11908553, ...,  0.58606274,
#          0.50192942,  0.42032679],
#        [ 1.57172834,  1.50562007,  0.50878234, ...,  1.04133219,
#          0.94544083,  0.06520418],
#        [ 0.0608662 , -0.02985272, -1.4374422 , ...,  0.26058302,
#          0.40066513,  0.60562969],
#        ...,
#        [-0.42171769, -0.11812151, -0.45785574, ..., -1.31531745,
#          0.49764282,  0.50721298],
#        [ 0.85475196,  0.72327309,  0.56917584, ..., -1.31531745,
#          0.16005214,  0.18169313],
#        [-1.01311366, -0.60370514, -0.76727104, ..., -1.31531745,
#         -0.47339699, -0.09964274]])

# %%
from sklearn.linear_model import ElasticNet

elastic_net = ElasticNet()
elastic_net.fit(X_train_s, y_train)
y_pred = elastic_net.predict(X_test_s)

# %%
plt.scatter(y_test, y_pred)
plt.show()

# %%
mae, mse, rmse, r_squared = evaluation(y_test, y_pred)

# %%
new_row = {"Model": "Elastic","MAE": mae, "MSE": mse, "RMSE": rmse, "R2 Score": r_squared}
evals = pd.concat([evals, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# ------------------------------

# %% [markdown]
#  #### Model Comparison

# %%
evals.sort_values(by="RMSE")
# Out:
#               Model           MAE           MSE           RMSE  R2 Score
# 2               SVR  62015.417148  1.520086e+10  123291.757127  0.791923
# 1     Random Forest  63275.173476  1.645099e+10  128261.417329  0.774810
# 3           XGBoost  90421.592005  2.375934e+10  154140.646607  0.674770
# 4             Ridge  92510.932458  2.622401e+10  161938.294580  0.641032
# 5             Lasso  92532.591264  2.622531e+10  161942.319236  0.641014
# 0  LinearRegression  92533.459107  2.622539e+10  161942.551557  0.641013
# 6           Elastic  91308.440044  2.909149e+10  170562.276447  0.601780

# %% [markdown]
# -----------------------------

# %% [markdown]
#  #### Hyper Parameter Tuning

# %% [markdown]
# * Applied to top 3 models from above.

# %% [markdown]
#  #### XGB

# %%
from sklearn.model_selection import GridSearchCV 

parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:squarederror'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

xgb_grid = GridSearchCV(XGBRegressor(),
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

# fitting the model for grid search 
xgb_grid.fit(X_train_s, y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# GridSearchCV(cv=2,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=5,
#              param_grid={'colsample_bytree': [0.7],
#                          'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7], 'min_child_weight': [4],
#                          'n_estimators': [500], 'nthread': [4],
#                          'objective': ['reg:squarederror'],
#                          'subsample': [0.7]},
#              verbose=True)

# %%
grid_predictions = xgb_grid.predict(X_test_s) 
mae, mse, rmse, r_squared = evaluation(y_test, grid_predictions)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# MAE: 62772.77579568115
# MSE: 17324991939.417416
# RMSE: 131624.435191257
# R2 Score: 0.7628463466381473
# ------------------------------

# %%
xgb_grid.predict(testing)
# Out:
# array([56746.086], dtype=float32)

# %% [markdown]
#  #### SVR

# %%
param_grid = {'C': [1000, 10000, 100000, 1000000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]}  
  
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
grid.fit(X_train_s, y_train)
grid_predictions = grid.predict(X_test_s)

mae, mse, rmse, r_squared = evaluation(y_test, grid_predictions)
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ...................C=1000, gamma=1;, score=0.003 total time=   0.4s
# [CV 2/5] END ..................C=1000, gamma=1;, score=-0.013 total time=   0.3s
# [CV 3/5] END ..................C=1000, gamma=1;, score=-0.035 total time=   0.2s
# [CV 4/5] END ..................C=1000, gamma=1;, score=-0.029 total time=   0.3s
# [CV 5/5] END ..................C=1000, gamma=1;, score=-0.025 total time=   0.2s
# [CV 1/5] END .................C=1000, gamma=0.1;, score=0.279 total time=   0.2s
# [CV 2/5] END .................C=1000, gamma=0.1;, score=0.272 total time=   0.2s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.157 total time=   0.3s
# [CV 4/5] END .................C=1000, gamma=0.1;, score=0.305 total time=   0.2s
# [CV 5/5] END .................C=1000, gamma=0.1;, score=0.281 total time=   0.2s
# [CV 1/5] END ................C=1000, gamma=0.01;, score=0.246 total time=   0.2s
# [CV 2/5] END ................C=1000, gamma=0.01;, score=0.233 total time=   0.2s
# [CV 3/5] END ................C=1000, gamma=0.01;, score=0.167 total time=   0.3s
# [CV 4/5] END ................C=1000, gamma=0.01;, score=0.250 total time=   0.3s
# [CV 5/5] END ................C=1000, gamma=0.01;, score=0.233 total time=   0.3s
# [CV 1/5] END ...............C=1000, gamma=0.001;, score=0.022 total time=   0.3s
# [CV 2/5] END ...............C=1000, gamma=0.001;, score=0.006 total time=   0.2s
# [CV 3/5] END ..............C=1000, gamma=0.001;, score=-0.009 total time=   0.3s
# [CV 4/5] END ..............C=1000, gamma=0.001;, score=-0.009 total time=   0.3s
# [CV 5/5] END ..............C=1000, gamma=0.001;, score=-0.005 total time=   0.2s
# [CV 1/5] END .............C=1000, gamma=0.0001;, score=-0.031 total time=   0.3s
# [CV 2/5] END .............C=1000, gamma=0.0001;, score=-0.049 total time=   0.3s
# [CV 3/5] END .............C=1000, gamma=0.0001;, score=-0.054 total time=   0.2s
# [CV 4/5] END .............C=1000, gamma=0.0001;, score=-0.073 total time=   0.3s
# [CV 5/5] END .............C=1000, gamma=0.0001;, score=-0.062 total time=   0.3s
# [CV 1/5] END ..................C=10000, gamma=1;, score=0.217 total time=   0.3s
# [CV 2/5] END ..................C=10000, gamma=1;, score=0.203 total time=   0.3s
# [CV 3/5] END ..................C=10000, gamma=1;, score=0.096 total time=   0.3s
# [CV 4/5] END ..................C=10000, gamma=1;, score=0.235 total time=   0.2s
# [CV 5/5] END ..................C=10000, gamma=1;, score=0.205 total time=   0.2s
# [CV 1/5] END ................C=10000, gamma=0.1;, score=0.578 total time=   0.3s
# [CV 2/5] END ................C=10000, gamma=0.1;, score=0.582 total time=   0.3s
# [CV 3/5] END ................C=10000, gamma=0.1;, score=0.401 total time=   0.3s
# [CV 4/5] END ................C=10000, gamma=0.1;, score=0.669 total time=   0.3s
# [CV 5/5] END ................C=10000, gamma=0.1;, score=0.581 total time=   0.3s
# [CV 1/5] END ...............C=10000, gamma=0.01;, score=0.559 total time=   0.3s
# [CV 2/5] END ...............C=10000, gamma=0.01;, score=0.551 total time=   0.2s
# [CV 3/5] END ...............C=10000, gamma=0.01;, score=0.433 total time=   0.3s
# [CV 4/5] END ...............C=10000, gamma=0.01;, score=0.620 total time=   0.2s
# [CV 5/5] END ...............C=10000, gamma=0.01;, score=0.557 total time=   0.3s
# [CV 1/5] END ..............C=10000, gamma=0.001;, score=0.297 total time=   0.3s
# [CV 2/5] END ..............C=10000, gamma=0.001;, score=0.282 total time=   0.3s
# [CV 3/5] END ..............C=10000, gamma=0.001;, score=0.220 total time=   0.3s
# [CV 4/5] END ..............C=10000, gamma=0.001;, score=0.306 total time=   0.2s
# [CV 5/5] END ..............C=10000, gamma=0.001;, score=0.287 total time=   0.3s
# [CV 1/5] END .............C=10000, gamma=0.0001;, score=0.024 total time=   0.2s
# [CV 2/5] END .............C=10000, gamma=0.0001;, score=0.008 total time=   0.2s
# [CV 3/5] END ............C=10000, gamma=0.0001;, score=-0.007 total time=   0.3s
# [CV 4/5] END ............C=10000, gamma=0.0001;, score=-0.007 total time=   0.3s
# [CV 5/5] END ............C=10000, gamma=0.0001;, score=-0.003 total time=   0.3s
# [CV 1/5] END .................C=100000, gamma=1;, score=0.667 total time=   0.5s
# [CV 2/5] END .................C=100000, gamma=1;, score=0.638 total time=   0.5s
# [CV 3/5] END .................C=100000, gamma=1;, score=0.397 total time=   0.5s
# [CV 4/5] END .................C=100000, gamma=1;, score=0.707 total time=   0.5s
# [CV 5/5] END .................C=100000, gamma=1;, score=0.618 total time=   0.5s
# [CV 1/5] END ...............C=100000, gamma=0.1;, score=0.791 total time=   0.3s
# [CV 2/5] END ...............C=100000, gamma=0.1;, score=0.813 total time=   0.3s
# [CV 3/5] END ...............C=100000, gamma=0.1;, score=0.663 total time=   0.3s
# [CV 4/5] END ...............C=100000, gamma=0.1;, score=0.857 total time=   0.3s
# [CV 5/5] END ...............C=100000, gamma=0.1;, score=0.807 total time=   0.4s
# [CV 1/5] END ..............C=100000, gamma=0.01;, score=0.694 total time=   0.3s
# [CV 2/5] END ..............C=100000, gamma=0.01;, score=0.698 total time=   0.3s
# [CV 3/5] END ..............C=100000, gamma=0.01;, score=0.583 total time=   0.3s
# [CV 4/5] END ..............C=100000, gamma=0.01;, score=0.762 total time=   0.3s
# [CV 5/5] END ..............C=100000, gamma=0.01;, score=0.702 total time=   0.3s
# [CV 1/5] END .............C=100000, gamma=0.001;, score=0.562 total time=   0.3s
# [CV 2/5] END .............C=100000, gamma=0.001;, score=0.555 total time=   0.3s
# [CV 3/5] END .............C=100000, gamma=0.001;, score=0.452 total time=   0.2s
# [CV 4/5] END .............C=100000, gamma=0.001;, score=0.616 total time=   0.3s
# [CV 5/5] END .............C=100000, gamma=0.001;, score=0.561 total time=   0.3s
# [CV 1/5] END ............C=100000, gamma=0.0001;, score=0.302 total time=   0.3s
# [CV 2/5] END ............C=100000, gamma=0.0001;, score=0.286 total time=   0.3s
# [CV 3/5] END ............C=100000, gamma=0.0001;, score=0.225 total time=   0.3s
# [CV 4/5] END ............C=100000, gamma=0.0001;, score=0.311 total time=   0.3s
# [CV 5/5] END ............C=100000, gamma=0.0001;, score=0.291 total time=   0.3s
# [CV 1/5] END ................C=1000000, gamma=1;, score=0.674 total time=   1.2s
# [CV 2/5] END ................C=1000000, gamma=1;, score=0.832 total time=   1.2s
# [CV 3/5] END ................C=1000000, gamma=1;, score=0.615 total time=   1.3s
# [CV 4/5] END ................C=1000000, gamma=1;, score=0.783 total time=   1.3s
# [CV 5/5] END ................C=1000000, gamma=1;, score=0.789 total time=   1.3s
# [CV 1/5] END ..............C=1000000, gamma=0.1;, score=0.737 total time=   1.8s
# [CV 2/5] END ..............C=1000000, gamma=0.1;, score=0.891 total time=   1.0s
# [CV 3/5] END ..............C=1000000, gamma=0.1;, score=0.807 total time=   1.6s
# [CV 4/5] END ..............C=1000000, gamma=0.1;, score=0.881 total time=   1.3s
# [CV 5/5] END ..............C=1000000, gamma=0.1;, score=0.893 total time=   1.2s
# [CV 1/5] END .............C=1000000, gamma=0.01;, score=0.772 total time=   0.4s
# [CV 2/5] END .............C=1000000, gamma=0.01;, score=0.796 total time=   0.4s
# [CV 3/5] END .............C=1000000, gamma=0.01;, score=0.701 total time=   0.3s
# [CV 4/5] END .............C=1000000, gamma=0.01;, score=0.845 total time=   0.3s
# [CV 5/5] END .............C=1000000, gamma=0.01;, score=0.801 total time=   0.4s
# [CV 1/5] END ............C=1000000, gamma=0.001;, score=0.662 total time=   0.3s
# [CV 2/5] END ............C=1000000, gamma=0.001;, score=0.664 total time=   0.3s
# [CV 3/5] END ............C=1000000, gamma=0.001;, score=0.565 total time=   0.3s
# [CV 4/5] END ............C=1000000, gamma=0.001;, score=0.729 total time=   0.3s
# [CV 5/5] END ............C=1000000, gamma=0.001;, score=0.673 total time=   0.3s
# [CV 1/5] END ...........C=1000000, gamma=0.0001;, score=0.553 total time=   0.3s
# [CV 2/5] END ...........C=1000000, gamma=0.0001;, score=0.547 total time=   0.3s
# [CV 3/5] END ...........C=1000000, gamma=0.0001;, score=0.442 total time=   0.3s
# [CV 4/5] END ...........C=1000000, gamma=0.0001;, score=0.606 total time=   0.3s
# [CV 5/5] END ...........C=1000000, gamma=0.0001;, score=0.552 total time=   0.2s
# MAE: 59284.97174734982
# MSE: 14228218777.419853
# RMSE: 119282.09747241977
# R2 Score: 0.8052366156534964
# ------------------------------

# %%
grid.predict(testing)
# Out:
# array([267901.83824053])

# %% [markdown]
#  #### Random Forest

# %%
# Number of trees in random forest
n_estimators = [500,1000]
# Maximum number of levels in tree
max_depth = [10,20]
max_depth.append(None)


# Create the random grid
param_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
grid.fit(X_train_s, y_train) 
grid_predictions = grid.predict(X_test_s)
mae, mse, rmse, r_squared = evaluation(y_test, grid_predictions)
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r_squared)
print("-"*30)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ....max_depth=10, n_estimators=500;, score=0.671 total time=   8.8s
# [CV 2/5] END ....max_depth=10, n_estimators=500;, score=0.880 total time=   9.0s
# [CV 3/5] END ....max_depth=10, n_estimators=500;, score=0.759 total time=   9.1s
# [CV 4/5] END ....max_depth=10, n_estimators=500;, score=0.846 total time=   8.9s
# [CV 5/5] END ....max_depth=10, n_estimators=500;, score=0.878 total time=   8.9s
# [CV 1/5] END ...max_depth=10, n_estimators=1000;, score=0.668 total time=  17.7s
# [CV 2/5] END ...max_depth=10, n_estimators=1000;, score=0.879 total time=  18.0s
# [CV 3/5] END ...max_depth=10, n_estimators=1000;, score=0.757 total time=  17.8s

# %%
grid.predict(testing)
# Out:
# array([157604.28572618])
